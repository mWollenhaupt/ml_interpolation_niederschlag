# %%
import pandas as pd
from math import sqrt
from datetime import datetime

# %%
# read relevant data
obs_file = '../DATA/00_stations_in_use.csv'
obs = pd.read_csv(obs_file, delimiter=';')

dgm_file = '../DATA/DGM/dgm200_nrw.csv'
with open (dgm_file, 'r') as file_in:
    lines = file_in.readlines()
    lines = [x.strip() for x in lines]
    header = lines[0]
    del lines[0]

# %%
# create header for file
n = 50
for i in range(n):
    header += ';dist_{};value_{}'.format(i+1, i+1)

# %%
# function to calculate n nearest stations
def calc_nearest_stations(dgm_point, stations, number=3):
    result = []
    dgm_east = float(dgm_point[0])
    dgm_north = float(dgm_point[1])
    dgm_up = float(dgm_point[2])
    for idx, row in stations.iterrows():
        dist = sqrt((dgm_east-row['east'])**2+(dgm_north-row['north'])**2+(dgm_up-row['up'])**2)
        result.append([dist, ':{}'.format(row['name'])])
    result.sort(key=lambda x: x[0])
    result = result[0:number]
    cr = ';'.join(str(e) for e in result)
    cr = cr.replace("'", '').replace('[', '').replace(']', '').replace(', :', ';')
    return cr

# %%
# calculate nearest neighbors for points of dgm, write to file
file = '../DATA/06_dgm_nearest_station-names.csv'
cc = 1
pc = 1
l = len(lines)
with open (file, 'a') as file_out: # open file to write
    file_out.write('{}\n'.format(header)) # write header
    for line in lines: # iterate dgm-file
        #compute progress
        perc = (cc/l)*100
        if perc > pc:
            print('{0}: {1:.1f}%'.format(datetime.now(), perc))
            pc+=1
        cc+=1
        # compute nearest neighbors
        dgm_point = line.split(';')
        file_out.write('{};{}\n'.format(line, calc_nearest_stations(dgm_point, obs, n)))
# Out:
# 2019-01-17 18:13:03.359335: 1.0%
# 2019-01-17 18:15:14.105265: 2.0%
# 2019-01-17 18:17:26.882386: 3.0%
# 2019-01-17 18:19:37.987677: 4.0%
# 2019-01-17 18:21:49.342965: 5.0%
# 2019-01-17 18:24:00.229516: 6.0%
# 2019-01-17 18:26:13.162314: 7.0%
# 2019-01-17 18:28:24.970711: 8.0%
# 2019-01-17 18:30:35.341655: 9.0%
# 2019-01-17 18:32:44.747472: 10.0%
# 2019-01-17 18:34:52.165381: 11.0%
# 2019-01-17 18:36:59.723912: 12.0%
# 2019-01-17 18:39:07.157443: 13.0%
# 2019-01-17 18:41:14.231615: 14.0%
# 2019-01-17 18:43:21.571402: 15.0%
# 2019-01-17 18:45:29.067435: 16.0%
# 2019-01-17 18:47:36.188478: 17.0%
# 2019-01-17 18:49:45.106343: 18.0%
# 2019-01-17 18:51:55.196042: 19.0%
# 2019-01-17 18:54:06.737720: 20.0%
# 2019-01-17 18:56:17.452401: 21.0%
# 2019-01-17 18:58:25.010933: 22.0%
# 2019-01-17 19:00:32.460091: 23.0%
# 2019-01-17 19:02:39.909248: 24.0%
# 2019-01-17 19:04:47.545903: 25.0%
# 2019-01-17 19:06:55.212326: 26.0%
# 2019-01-17 19:09:03.630201: 27.0%
# 2019-01-17 19:11:11.188732: 28.0%
# 2019-01-17 19:13:19.653485: 29.0%
# 2019-01-17 19:15:26.837025: 30.0%
# 2019-01-17 19:17:34.208063: 31.0%
# 2019-01-17 19:19:42.094709: 32.0%
# 2019-01-17 19:21:50.918824: 33.0%
