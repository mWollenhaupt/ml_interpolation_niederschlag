# %%
import pandas as pd
from datetime import datetime
from pathlib import Path

# %%
# read relevant data - create temporal file with new order
temp_file = '../DATA/05_temp.csv'
temp = Path(temp_file)
if temp.is_file() == False:
    file = '../DATA/04_station_nearest_stations-names.csv'
    df = pd.read_csv(file, delimiter=';', encoding='latin1')
    df = df.sort_values(['timestamp', 'name'])
    df.to_csv('../DATA/05_temp.csv', sep=';', index=False)

# %%
# read in re-orderd temporary file
with open ('../DATA/05_temp.csv', 'r', encoding='utf-8') as file:
    lines = file.readlines()
lines = [x.strip() for x in lines]
header = lines[0]
del lines[0]

# %%
# replace station-names by their values measured at each day
n = 50
cc = 1
pc = 1
le = len(lines)/129
with open ('../DATA/05_station_nearest_stations.csv', 'a') as file_out:
    file_out.write('{}\n'.format(header))
    for date in range(int(len(lines)/129)):
        # compute progress
        perc = (cc/le)*100
        if perc > pc:
            print('{0}: {1:.1f}%'.format(datetime.now(), perc))
            pc+=1
        cc+=1
        # replace names with values
        l = int(date*129)
        h = int((date+1)*129)
        data = lines[l:h]
        d = {}
        for line in data:
            split=line.split(';')
            d[split[0]] = split[5]
        for line in data:
            split=line.split(';')
            for i in range(n):
                name = split[7+(2*i)]
                split[7+(2*i)] = d[name]
            cr = ';'.join(str(e) for e in split)
            file_out.write('{}\n'.format(cr))
# Out:
# 2019-01-17 17:27:56.640227: 1.0%
# 2019-01-17 17:27:56.937090: 2.0%
# 2019-01-17 17:27:57.187082: 3.0%
# 2019-01-17 17:27:57.452698: 4.0%
# 2019-01-17 17:27:57.718316: 5.0%
# 2019-01-17 17:27:57.983933: 6.0%
# 2019-01-17 17:27:58.249549: 7.0%
# 2019-01-17 17:27:58.562038: 8.0%
# 2019-01-17 17:27:58.827656: 9.0%
# 2019-01-17 17:27:59.077648: 10.0%
# 2019-01-17 17:27:59.358888: 11.0%
# 2019-01-17 17:27:59.624505: 12.0%
# 2019-01-17 17:27:59.890121: 13.0%
# 2019-01-17 17:28:00.155738: 14.0%
# 2019-01-17 17:28:00.421356: 15.0%
# 2019-01-17 17:28:00.718222: 16.0%
# 2019-01-17 17:28:00.968214: 17.0%
# 2019-01-17 17:28:01.265079: 18.0%
# 2019-01-17 17:28:01.515073: 19.0%
# 2019-01-17 17:28:01.765063: 20.0%
# 2019-01-17 17:28:02.030682: 21.0%
# 2019-01-17 17:28:02.280673: 22.0%
# 2019-01-17 17:28:02.593162: 23.0%
# 2019-01-17 17:28:02.952526: 24.0%
# 2019-01-17 17:28:03.311891: 25.0%
# 2019-01-17 17:28:03.561883: 26.0%
# 2019-01-17 17:28:03.811875: 27.0%
# 2019-01-17 17:28:04.077491: 28.0%
# 2019-01-17 17:28:04.327485: 29.0%
# 2019-01-17 17:28:04.593102: 30.0%
# 2019-01-17 17:28:04.858717: 31.0%
# 2019-01-17 17:28:05.186834: 32.0%
# 2019-01-17 17:28:05.436825: 33.0%
# 2019-01-17 17:28:05.702442: 34.0%
# 2019-01-17 17:28:05.952434: 35.0%
# 2019-01-17 17:28:06.218051: 36.0%
