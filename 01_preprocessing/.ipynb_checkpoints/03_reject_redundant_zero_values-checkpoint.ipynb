# %%
import pandas as pd
from datetime import datetime

# %%
# read relevant data
file_in = '../DATA/02_observations_high-data-volume.csv'
df = pd.read_csv(file_in, delimiter=';')

# %%
# group data by timestamp
groups = df.groupby('timestamp')

# %%
# function to check, if there where only zero-values for a day
def onlyZeroData(dataframe):
    for row in dataframe.iterrows():
        value = row[1]['value']
        if value != 0:
            return False
    return True

# %%
# run function for each group(day), write to non-redundant groups to csv-file
file_out = '../DATA/03_valid_observations.csv'
once = False
header = True

l = len(groups)
pc = 1
cc = 1

for name, group in groups:
    # compute progress
    perc = (cc/l)*100
    if perc > pc:
        print('{0}: {1:.1f}%'.format(datetime.now(), perc))
        pc+=1
    cc+=1
    group.sort_values(['timestamp', 'name'])
    current_df = onlyZeroData(group)
    if once == False:
        if current_df == True:
            if header:
                group.to_csv(file_out, sep=';', index=False, mode='a')
                once = True
                header = False
            else:
                group.to_csv(file_out, sep=';', header=False, index=False, mode='a')
                once = True
    if current_df == False:
        if header:
            group.to_csv(file_out, sep=';', index=False, mode='a')
            header = False
        else:
            group.to_csv(file_out, sep=';', header=False, index=False, mode='a')
# Out:
# 2019-01-17 14:30:37.005856: 1.1%
# 2019-01-17 14:30:37.221995: 2.1%
# 2019-01-17 14:30:37.375635: 3.2%
# 2019-01-17 14:30:37.475895: 4.0%
# 2019-01-17 14:30:37.591785: 5.1%
# 2019-01-17 14:30:37.676419: 6.2%
# 2019-01-17 14:30:37.754547: 7.0%
# 2019-01-17 14:30:37.839186: 8.1%
# 2019-01-17 14:30:37.923823: 9.2%
# 2019-01-17 14:30:37.970696: 10.0%
# 2019-01-17 14:30:38.024084: 11.1%
# 2019-01-17 14:30:38.093096: 12.1%
# 2019-01-17 14:30:38.139971: 13.0%
# 2019-01-17 14:30:38.177724: 14.1%
# 2019-01-17 14:30:38.224604: 15.1%
# 2019-01-17 14:30:38.277983: 16.0%
# 2019-01-17 14:30:38.324864: 17.1%
# 2019-01-17 14:30:38.371735: 18.1%
# 2019-01-17 14:30:38.393875: 19.0%
# 2019-01-17 14:30:38.440750: 20.1%
# 2019-01-17 14:30:38.478506: 21.1%
# 2019-01-17 14:30:38.509761: 22.0%
# 2019-01-17 14:30:38.541010: 23.1%
# 2019-01-17 14:30:38.578766: 24.1%
# 2019-01-17 14:30:38.610022: 25.2%
# 2019-01-17 14:30:38.641271: 26.1%
# 2019-01-17 14:30:38.679026: 27.1%
# 2019-01-17 14:30:38.710282: 28.2%
# 2019-01-17 14:30:38.725906: 29.0%
# 2019-01-17 14:30:38.757155: 30.1%
# 2019-01-17 14:30:38.794916: 31.2%
# 2019-01-17 14:30:38.810539: 32.0%
# 2019-01-17 14:30:38.841790: 33.1%
# 2019-01-17 14:30:38.879546: 34.2%
# 2019-01-17 14:30:38.895177: 35.0%
# 2019-01-17 14:30:38.926426: 36.1%
# 2019-01-17 14:30:38.957674: 37.1%
# 2019-01-17 14:30:38.979806: 38.0%
